# %% [markdown]
# # Import Packages

# %%
import gc

import pandas as pd
import numpy as np

import surprise 
from surprise.model_selection import cross_validate
from surprise import KNNWithMeans
from surprise.model_selection import GridSearchCV

# %% [markdown]
# # Load Data

# %%
df_ratings = pd.read_csv('../data/task2/ratings_small.csv')

print(df_ratings.shape)
df_ratings.head()
# Out:
# (100004, 4)
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
##### transform dataset #####
df_ratings = df_ratings[['userId', 'movieId', 'rating']]

movie_reader = surprise.Reader(rating_scale=(1, 5))
data = surprise.Dataset.load_from_df(df_ratings, movie_reader)

del(df_ratings)

# %% [markdown]
# # Analysis

# %%
class PMF(surprise.AlgoBase):

    def __init__(self, learning_rate, num_epochs, num_factors):

        self.alpha = learning_rate 
        self.num_epochs = num_epochs
        self.num_factors = num_factors
        
        
    def fit(self, train):
        
        P = np.random.normal(0, 0.1, (train.n_users, self.num_factors))
        Q = np.random.normal(0, 0.1, (train.n_items, self.num_factors))

        for epoch in range(self.num_epochs):
            for u,i,r_ui in train.all_ratings():
                residual = r_ui - np.dot(P[u], Q[i])
                temp = P[u, :] 
                
                P[u,:] += self.alpha * residual * Q[i]
                Q[i,:] += self.alpha * residual * temp 

                
        self.P = P
        self.Q = Q

        self.trainset = train
    
    
    def estimate(self, u, i):

        if self.trainset.knows_user(u) and self.trainset.knows_item(i):
            nanCheck = np.dot(self.P[u], self.Q[i])
            
            if np.isnan(nanCheck):
                return self.trainset.global_mean
            else:
                return np.dot(self.P[u,:],self.Q[i,:])
        
        else:
            return self.trainset.global_mean

# %% [markdown]
# ## 3(c), 3(d)

# %%
##### compute rmse and mae for Probabilistic Matrix Factorization (PMF) #####
pmf = PMF(learning_rate=0.05, num_epochs=5, num_factors=10)

cross_validate(pmf, data, 
               measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm PMF on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0493  1.0434  1.0453  1.0742  1.0534  1.0531  0.0111
# MAE (testset)     0.8077  0.8069  0.8026  0.8243  0.8102  0.8103  0.0074
# Fit time          1.92    1.87    1.86    1.86    1.85    1.87    0.02
# Test time         0.12    0.13    0.17    0.12    0.17    0.14    0.02
# {'test_rmse': array([1.04926729, 1.04341216, 1.04526324, 1.07419732, 1.05343396]),
#  'test_mae': array([0.8076676 , 0.80692042, 0.8026196 , 0.82430141, 0.81022014]),
#  'fit_time': (1.9190654754638672,
#   1.8726131916046143,
#   1.8603920936584473,
#   1.8614134788513184,
#   1.84981107711792),
#  'test_time': (0.11936211585998535,
#   0.13021349906921387,
#   0.16975975036621094,
#   0.11609244346618652,
#   0.1739966869354248)}

# %%
##### compute rmse and mae for User-based Collaborative Filtering #####
##### name: cosine #####
sim_options = {'name': 'cosine', 'user_based': True}; user_algo = KNNWithMeans(sim_options=sim_options)

cross_validate(user_algo, data, 
               measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9270  0.9191  0.9250  0.9118  0.9247  0.9215  0.0055
# MAE (testset)     0.7104  0.7053  0.7096  0.7000  0.7097  0.7070  0.0039
# Fit time          0.14    0.17    0.23    0.20    0.18    0.19    0.03
# Test time         0.82    0.83    0.92    0.88    0.79    0.85    0.05
# {'test_rmse': array([0.92701321, 0.91907191, 0.92504458, 0.91182768, 0.9246893 ]),
#  'test_mae': array([0.7103943 , 0.70533666, 0.70962461, 0.69997665, 0.70968548]),
#  'fit_time': (0.14395737648010254,
#   0.16860198974609375,
#   0.2346024513244629,
#   0.20336008071899414,
#   0.18266582489013672),
#  'test_time': (0.8151421546936035,
#   0.8307774066925049,
#   0.9164149761199951,
#   0.8835556507110596,
#   0.7948973178863525)}

# %%
##### compute rmse and mae for Item-based Collaborative Filtering #####
##### name: cosine #####
sim_options = {'name': 'cosine', 'user_based': False}; item_algo = KNNWithMeans(sim_options=sim_options)

cross_validate(item_algo, data, 
               measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9230  0.9298  0.9228  0.9176  0.9373  0.9261  0.0068
# MAE (testset)     0.7093  0.7120  0.7076  0.7044  0.7181  0.7103  0.0046
# Fit time          3.28    3.34    3.46    3.34    3.43    3.37    0.07
# Test time         3.71    3.59    3.85    3.65    3.74    3.71    0.09
# {'test_rmse': array([0.92297538, 0.92977994, 0.92278553, 0.91760466, 0.93726409]),
#  'test_mae': array([0.70931316, 0.7120402 , 0.70763508, 0.70440726, 0.71811834]),
#  'fit_time': (3.283848762512207,
#   3.338536024093628,
#   3.4628963470458984,
#   3.3390493392944336,
#   3.433276653289795),
#  'test_time': (3.7141618728637695,
#   3.593128204345703,
#   3.8541290760040283,
#   3.6477551460266113,
#   3.7387216091156006)}

# %% [markdown]
# ## 3(e)

# %%
##### compute rmse and mae for User-based Collaborative Filtering #####
##### name: msd #####
sim_options = {'name': 'msd', 'user_based': True}; user_algo = KNNWithMeans(sim_options=sim_options)

cross_validate(user_algo, data, 
               measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9213  0.9240  0.9136  0.9176  0.9184  0.9190  0.0035
# MAE (testset)     0.7067  0.7057  0.6985  0.7033  0.7031  0.7035  0.0028
# Fit time          0.11    0.15    0.11    0.14    0.11    0.12    0.02
# Test time         0.81    0.87    0.94    0.85    0.82    0.86    0.04
# {'test_rmse': array([0.92127364, 0.92401114, 0.91360495, 0.91761804, 0.91837236]),
#  'test_mae': array([0.7066581 , 0.70571853, 0.69848866, 0.70326436, 0.7031458 ]),
#  'fit_time': (0.10574698448181152,
#   0.15415620803833008,
#   0.1122746467590332,
#   0.14043688774108887,
#   0.10959768295288086),
#  'test_time': (0.8139958381652832,
#   0.8715102672576904,
#   0.9356298446655273,
#   0.8533451557159424,
#   0.822089433670044)}

# %%
##### compute rmse and mae for Item-based Collaborative Filtering #####
##### name: msd #####
sim_options = {'name': 'msd', 'user_based': False}; item_algo = KNNWithMeans(sim_options=sim_options)

cross_validate(item_algo, data, 
               measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9179  0.9123  0.9121  0.9265  0.9074  0.9152  0.0066
# MAE (testset)     0.7032  0.6972  0.6968  0.7072  0.6982  0.7005  0.0040
# Fit time          2.08    2.17    2.25    2.21    2.25    2.19    0.07
# Test time         3.69    3.82    3.94    3.91    3.89    3.85    0.09
# {'test_rmse': array([0.91794877, 0.91230046, 0.91206795, 0.92651742, 0.90737439]),
#  'test_mae': array([0.7032312 , 0.69719026, 0.69684267, 0.70715609, 0.6982284 ]),
#  'fit_time': (2.0774383544921875,
#   2.1701581478118896,
#   2.2545392513275146,
#   2.2075233459472656,
#   2.251655101776123),
#  'test_time': (3.6900172233581543,
#   3.8153743743896484,
#   3.9378738403320312,
#   3.9068808555603027,
#   3.890315055847168)}

# %%
##### compute rmse and mae for User-based Collaborative Filtering #####
##### name: pearson #####
sim_options = {'name': 'pearson', 'user_based': True}; user_algo = KNNWithMeans(sim_options=sim_options)

cross_validate(user_algo, data, 
               measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9304  0.9218  0.9265  0.9279  0.9127  0.9239  0.0062
# MAE (testset)     0.7053  0.7041  0.7076  0.7079  0.6983  0.7046  0.0035
# Fit time          0.23    0.25    0.22    0.30    0.21    0.24    0.03
# Test time         0.84    0.87    0.98    0.84    0.84    0.87    0.06
# {'test_rmse': array([0.93037588, 0.92184808, 0.92653583, 0.92793188, 0.91273066]),
#  'test_mae': array([0.70532283, 0.70410408, 0.70758262, 0.70787063, 0.69829003]),
#  'fit_time': (0.23227906227111816,
#   0.25476789474487305,
#   0.21914029121398926,
#   0.29950785636901855,
#   0.21060633659362793),
#  'test_time': (0.835533857345581,
#   0.8686585426330566,
#   0.9841725826263428,
#   0.8445603847503662,
#   0.8417208194732666)}

# %%
##### compute rmse and mae for Item-based Collaborative Filtering #####
##### name: pearson #####
sim_options = {'name': 'pearson', 'user_based': False}; item_algo = KNNWithMeans(sim_options=sim_options)

cross_validate(item_algo, data, 
               measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9312  0.9202  0.9339  0.9356  0.9211  0.9284  0.0065
# MAE (testset)     0.7088  0.7059  0.7102  0.7086  0.7044  0.7076  0.0021
# Fit time          4.55    4.59    4.59    4.44    4.48    4.53    0.06
# Test time         3.72    3.79    3.78    3.63    3.75    3.73    0.06
# {'test_rmse': array([0.93120639, 0.92016492, 0.93387879, 0.93560859, 0.92107981]),
#  'test_mae': array([0.70879431, 0.70592712, 0.71022951, 0.70858843, 0.7043958 ]),
#  'fit_time': (4.551377058029175,
#   4.589977025985718,
#   4.593186855316162,
#   4.437203884124756,
#   4.482363939285278),
#  'test_time': (3.7184770107269287,
#   3.7869553565979004,
#   3.7829689979553223,
#   3.6326050758361816,
#   3.7521798610687256)}

# %% [markdown]
# ## 3(f), 3(g)

# %%
##### examine neigbouring impacts on User-based Collaborative Filtering #####
sim_options = {'name': ['cosine', 'msd', 'pearson'], 'user_based': [True]}
param_grid = {'sim_options': sim_options, 'k': [25, 30, 35, 40, 45, 50, 60, 70, 80, 90, 100, 150, 200, 300]}

grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse'], cv=5)
grid_search.fit(data)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
print(grid_search.best_params['rmse']); print(grid_search.best_score['rmse'])
# Out:
# {'sim_options': {'name': 'msd', 'user_based': True}, 'k': 40}
# 0.9192799310583138

# %%
##### grid_searchine neigbouring impacts on Item-based Collaborative Filtering #####
sim_options = {'name': ['cosine', 'msd', 'pearson'], 'user_based': [False]}
param_grid = {'sim_options': sim_options, 'k': [50, 60, 70, 80, 90, 100, 150, 200, 300]}

grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse'], cv=5)
grid_search.fit(data)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
print(grid_search.best_params['rmse']); print(grid_search.best_score['rmse'])
# Out:
# {'sim_options': {'name': 'msd', 'user_based': False}, 'k': 150}
# 0.9097211832400618

# %%
##### find optimum neighbours for User-Based Collaborative Filtering #####
sim_options = {'name': 'msd', 'user_based': True}

for k in range(5, 250, 5):
    print('k = ', k)
    
    user_algo = KNNWithMeans(sim_options=sim_options, k = k)
    
    cross_validate(user_algo, data, 
                   measures=['RMSE'], cv=5, verbose=True)
    
    print('\n')
# Out:
# k =  5
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9154  0.9265  0.9215  0.9198  0.9207  0.9208  0.0035
# Fit time          0.14    0.11    0.12    0.12    0.12    0.12    0.01
# Test time         1.03    0.88    0.93    1.04    0.88    0.95    0.07
#
#
# k =  150
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9195  0.9242  0.9172  0.9306  0.9101  0.9203  0.0069
# Fit time          0.10    0.11    0.12    0.12    0.12    0.11    0.01
# Test time         0.90    0.88    0.97    0.92    0.97    0.93    0.04
#
#
# k =  155
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9240  0.9246  0.9270  0.9144  0.9151  0.9210  0.0052
# Fit time          0.10    0.11    0.12    0.13    0.16    0.12    0.02
# Test time         0.88    0.88    0.87    0.91    0.96    0.90    0.03
#
#
# k =  160
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9290  0.9198  0.9219  0.9131  0.9223  0.9212  0.0051
# Fit time          0.14    0.16    0.16    0.12    0.12    0.14    0.02
# Test time         1.10    0.90    0.94    1.00    0.93    0.97    0.07
#
#
# k =  165
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9175  0.9272  0.9194  0.9206  0.9181  0.9206  0.0035
# Fit time          0.10    0.12    0.11    0.12    0.12    0.11    0.01
# Test time         0.94    0.86    0.87    0.88    0.98    0.91    0.05
#
#
# k =  170
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9264  0.9153  0.9223  0.9145  0.9178  0.9193  0.0045
# Fit time          0.10    0.12    0.12    0.12    0.11    0.11    0.01
# Test time         0.86    0.90    0.87    0.86    0.87    0.87    0.01
#
#
# k =  175
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9165  0.9281  0.9158  0.9174  0.9270  0.9210  0.0054
# Fit time          0.10    0.12    0.12    0.12    0.12    0.11    0.01
# Test time         0.87    0.85    0.87    1.00    0.85    0.89    0.05
#
#
# k =  180
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9200  0.9203  0.9278  0.9173  0.9208  0.9212  0.0035
# Fit time          0.11    0.12    0.13    0.12    0.12    0.12    0.01
# Test time         0.86    0.86    0.85    0.85    0.86    0.86    0.01
#
#
# k =  185
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9189  0.9183  0.9183  0.9215  0.9220  0.9198  0.0016
# Fit time          0.10    0.11    0.12    0.12    0.11    0.11    0.01
# Test time         0.85    0.85    0.98    0.84    0.85    0.87    0.05
#
#
# k =  190
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9213  0.9200  0.9152  0.9207  0.9294  0.9213  0.0046
# Fit time          0.10    0.12    0.12    0.11    0.11    0.11    0.01
# Test time         0.96    0.85    0.85    0.94    0.85    0.89    0.05
#
#
# k =  195
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9206  0.9197  0.9340  0.9121  0.9185  0.9210  0.0072
# Fit time          0.10    0.12    0.11    0.11    0.11    0.11    0.01
# Test time         0.85    0.94    0.85    0.84    0.96    0.89    0.05
#
#
# k =  200
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9194  0.9240  0.9272  0.9115  0.9251  0.9215  0.0056
# Fit time          0.10    0.11    0.11    0.12    0.12    0.11    0.01
# Test time         0.85    0.84    0.96    0.84    0.82    0.86    0.05
#
#
# k =  205
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9231  0.9203  0.9182  0.9229  0.9222  0.9213  0.0019
# Fit time          0.10    0.11    0.12    0.13    0.12    0.11    0.01
# Test time         0.95    0.84    0.84    0.94    0.83    0.88    0.05
#
#
# k =  210
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9207  0.9191  0.9241  0.9131  0.9238  0.9202  0.0040
# Fit time          0.10    0.13    0.12    0.13    0.13    0.12    0.01
# Test time         0.88    0.95    0.87    1.04    0.94    0.93    0.06
#
#
# k =  215
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9290  0.9252  0.9176  0.9171  0.9129  0.9204  0.0059
# Fit time          0.16    0.13    0.18    0.18    0.13    0.15    0.02
# Test time         0.92    0.95    1.00    0.93    0.95    0.95    0.03
#
#
# k =  220
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9187  0.9201  0.9120  0.9179  0.9289  0.9195  0.0054
# Fit time          0.10    0.17    0.12    0.12    0.12    0.13    0.02
# Test time         1.08    0.92    0.87    0.96    0.95    0.96    0.07
#
#
# k =  225
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9252  0.9108  0.9296  0.9115  0.9195  0.9193  0.0074
# Fit time          0.10    0.18    0.17    0.16    0.12    0.15    0.03
# Test time         1.19    1.08    1.05    1.07    1.07    1.09    0.05
#
#
# k =  230
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9216  0.9143  0.9203  0.9225  0.9215  0.9201  0.0030
# Fit time          0.10    0.11    0.11    0.14    0.12    0.12    0.01
# Test time         0.85    0.87    0.85    0.90    0.87    0.87    0.02
#
#
# k =  235
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9201  0.9168  0.9286  0.9170  0.9182  0.9201  0.0044
# Fit time          0.10    0.11    0.12    0.11    0.16    0.12    0.02
# Test time         1.00    0.88    0.85    1.38    0.94    1.01    0.19
#
#
# k =  240
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9313  0.9116  0.9210  0.9223  0.9183  0.9209  0.0064
# Fit time          0.15    0.11    0.12    0.13    0.13    0.13    0.01
# Test time         1.02    0.88    0.88    0.95    0.88    0.92    0.06
#
#
# k =  245
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9215  0.9143  0.9240  0.9218  0.9298  0.9223  0.0050
# Fit time          0.14    0.12    0.12    0.13    0.17    0.13    0.02
# Test time         0.95    0.84    1.04    0.97    0.89    0.94    0.07

# %%
##### find optimum neighbours for Item-Based Collaborative Filtering #####
sim_options = {'name': 'msd', 'user_based': False}

for k in range(5, 250, 5):
    print('k = ', k)
    
    item_algo = KNNWithMeans(sim_options=sim_options, k = k)
    
    cross_validate(item_algo, data, 
                   measures=['RMSE'], cv=5, verbose=True)
    
    print('\n')
# Out:
# k =  5
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9806  0.9891  0.9753  0.9607  0.9789  0.9769  0.0093
# Fit time          2.28    2.20    2.17    2.39    2.19    2.25    0.08
# Test time         3.19    3.29    3.12    3.16    2.98    3.15    0.10
#
#
# k =  10
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9423  0.9525  0.9353  0.9522  0.9325  0.9430  0.0083
# Fit time          2.14    2.27    2.29    2.41    2.31    2.29    0.09
# Test time         3.06    3.37    3.21    3.59    3.45    3.34    0.18
#
#
# k =  15
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9339  0.9395  0.9286  0.9168  0.9253  0.9288  0.0077
# Fit time          2.21    2.20    2.18    2.24    2.30    2.23    0.04
# Test time         3.39    3.32    3.30    3.31    3.55    3.38    0.09
#
#
# k =  20
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9206  0.9196  0.9208  0.9229  0.9325  0.9233  0.0047
# Fit time          2.16    2.15    2.18    2.36    2.13    2.20    0.08
# Test time         3.33    3.44    3.46    3.44    3.33    3.40    0.06
#
#
# k =  25
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9233  0.9201  0.9177  0.9193  0.9150  0.9191  0.0027
# Fit time          2.13    2.18    2.44    2.65    2.63    2.41    0.22
# Test time         3.88    3.52    4.16    5.02    4.19    4.15    0.50
#
#
# k =  30
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9181  0.9138  0.9143  0.9152  0.9202  0.9163  0.0025
# Fit time          2.13    2.29    2.36    2.30    2.25    2.27    0.08
# Test time         3.70    4.00    4.41    4.03    3.61    3.95    0.28
#
#
# k =  35
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9058  0.9162  0.9194  0.9088  0.9034  0.9107  0.0061
# Fit time          2.13    2.22    2.34    2.19    2.22    2.22    0.07
# Test time         4.75    4.88    4.70    4.69    4.78    4.76    0.07
#
#
# k =  110
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9088  0.9106  0.9124  0.9152  0.9018  0.9098  0.0045
# Fit time          2.14    2.29    2.20    2.19    2.29    2.22    0.06
# Test time         4.84    4.65    4.62    4.88    4.52    4.70    0.14
#
#
# k =  115
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9090  0.9056  0.9159  0.9076  0.9149  0.9106  0.0041
# Fit time          2.13    2.22    2.37    2.29    2.15    2.23    0.09
# Test time         4.55    5.13    5.10    4.85    4.75    4.88    0.22
#
#
# k =  120
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9083  0.9125  0.9126  0.9152  0.9077  0.9113  0.0028
# Fit time          2.21    2.23    2.19    2.25    2.22    2.22    0.02
# Test time         4.83    4.73    5.19    4.82    4.90    4.89    0.16
#
#
# k =  125
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9120  0.9087  0.9066  0.9155  0.9071  0.9100  0.0033
# Fit time          2.39    2.26    2.24    2.22    2.22    2.27    0.06
# Test time         5.05    4.92    4.84    4.77    4.71    4.86    0.12
#
#
# k =  130
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9052  0.9034  0.9085  0.9161  0.9201  0.9107  0.0064
# Fit time          2.16    2.25    2.17    2.17    2.20    2.19    0.03
# Test time         4.96    4.99    4.97    5.21    5.05    5.04    0.09
#
#
# k =  135
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9111  0.9154  0.9141  0.9091  0.8992  0.9098  0.0058
# Fit time          2.13    2.19    2.19    2.20    2.19    2.18    0.02
# Test time         4.80    4.76    4.91    4.76    4.78    4.80    0.06
#
#
# k =  140
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9155  0.9130  0.9097  0.9054  0.9072  0.9101  0.0037
# Fit time          2.15    2.20    2.22    2.28    2.23    2.22    0.04
# Test time         4.78    5.15    4.98    5.00    5.14    5.01    0.13
#
#
# k =  145
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9158  0.9107  0.9060  0.9125  0.9075  0.9105  0.0035
# Fit time          2.14    2.29    2.25    2.28    2.28    2.25    0.06
# Test time         5.36    5.27    5.26    5.01    5.39    5.26    0.14
#
#
# k =  150
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9091  0.9090  0.9085  0.9167  0.9088  0.9104  0.0032
# Fit time          2.15    2.34    2.18    2.17    2.19    2.21    0.07
# Test time         5.16    5.04    5.03    4.91    4.94    5.02    0.09
#
#
# k =  155
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9041  0.9011  0.9192  0.9125  0.9134  0.9100  0.0066
# Fit time          2.14    2.16    2.24    2.17    2.22    2.19    0.04
# Test time         5.03    5.04    5.06    5.19    5.36    5.14    0.13
#
#
# k =  160
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9113  0.9074  0.9091  0.9116  0.9168  0.9112  0.0032
# Fit time          2.27    2.27    2.30    2.33    2.45    2.33    0.07
# Test time         5.21    5.60    5.41    5.43    5.50    5.43    0.13
#
#
# k =  165
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9106  0.9094  0.9142  0.9098  0.9035  0.9095  0.0034
# Fit time          2.23    2.32    2.19    2.21    2.20    2.23    0.05
# Test time         5.51    5.50    5.24    5.05    5.04    5.27    0.21
#
#
# k =  170
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9105  0.9111  0.9092  0.9062  0.9102  0.9095  0.0017
# Fit time          2.14    2.21    2.35    2.24    2.27    2.24    0.07
# Test time         5.08    5.19    5.21    5.15    5.30    5.19    0.07
#
#
# k =  175
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9121  0.9095  0.9129  0.9100  0.9026  0.9094  0.0036
# Fit time          2.15    2.24    2.27    2.26    2.28    2.24    0.05
# Test time         5.40    5.48    5.17    5.41    5.73    5.44    0.18
#
#
# k =  180
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9110  0.9124  0.9044  0.9121  0.9159  0.9112  0.0038
# Fit time          2.26    2.23    2.27    2.25    2.18    2.24    0.03
# Test time         5.57    5.15    5.71    5.26    5.41    5.42    0.20
#
#
# k =  185
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9090  0.9161  0.9142  0.9064  0.9084  0.9108  0.0037
# Fit time          2.15    2.30    2.25    2.27    2.19    2.23    0.06
# Test time         5.20    5.37    5.40    5.38    5.08    5.28    0.12
#
#
# k =  190
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9144  0.9023  0.9125  0.9093  0.9097  0.9096  0.0041
# Fit time          2.12    2.24    2.17    2.17    2.26    2.19    0.05
# Test time         5.20    5.14    5.37    5.30    5.48    5.30    0.12
#
#
# k =  195
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9106  0.9136  0.9124  0.9150  0.8939  0.9091  0.0077
# Fit time          2.13    2.21    2.16    2.21    2.19    2.18    0.03
# Test time         5.10    5.35    5.41    5.25    5.83    5.39    0.25
#
#
# k =  200
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9164  0.9094  0.9043  0.9075  0.9164  0.9108  0.0048
# Fit time          2.17    2.17    2.23    2.26    2.20    2.21    0.04
# Test time         5.64    5.30    5.48    5.54    5.48    5.49    0.11
#
#
# k =  205
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9032  0.9211  0.9129  0.9070  0.9083  0.9105  0.0061
# Fit time          2.19    2.20    2.26    2.22    2.39    2.25    0.07
# Test time         5.40    5.57    5.41    5.35    5.74    5.50    0.14
#
#
# k =  210
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9037  0.9228  0.9134  0.9054  0.9113  0.9113  0.0068
# Fit time          2.26    2.19    2.19    2.17    2.16    2.20    0.03
# Test time         5.64    5.28    5.37    5.24    5.31    5.37    0.14
#
#
# k =  215
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9099  0.9136  0.9064  0.9085  0.9115  0.9100  0.0025
# Fit time          2.13    2.27    2.33    2.29    2.21    2.25    0.07
# Test time         5.42    6.33    6.40    5.39    5.36    5.78    0.48
#
#
# k =  220
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9097  0.9115  0.9108  0.9159  0.9018  0.9100  0.0046
# Fit time          2.14    2.16    2.18    2.18    2.17    2.17    0.02
# Test time         5.32    5.48    5.41    5.36    5.46    5.41    0.06
#
#
# k =  225
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9137  0.9103  0.9103  0.9074  0.9093  0.9102  0.0021
# Fit time          2.17    2.20    2.16    2.17    2.19    2.18    0.02
# Test time         5.45    5.45    5.52    5.48    5.46    5.47    0.03
#
#
# k =  230
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9016  0.9132  0.9068  0.9143  0.9220  0.9116  0.0069
# Fit time          2.18    2.18    2.20    2.18    2.33    2.21    0.06
# Test time         5.54    5.42    5.42    5.70    6.27    5.67    0.32
#
#
# k =  235
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9006  0.9129  0.9091  0.9108  0.9167  0.9100  0.0054
# Fit time          2.32    2.27    2.32    2.19    2.19    2.26    0.06
# Test time         6.11    6.16    5.25    5.38    5.73    5.73    0.37
#
#
# k =  240
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9016  0.9073  0.9167  0.9207  0.9080  0.9109  0.0069
# Fit time          2.23    2.26    2.19    2.20    2.21    2.22    0.03
# Test time         5.37    5.46    5.49    5.35    5.35    5.41    0.06
#
#
# k =  245
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9131  0.9096  0.9099  0.9083  0.9098  0.9101  0.0016
# Fit time          2.15    2.19    2.20    2.19    2.29    2.20    0.05
# Test time         5.46    5.47    5.31    5.49    5.69    5.48    0.12
